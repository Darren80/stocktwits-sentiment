# %%
# %pip install git+https://github.com/trevorhobenshield/twitter-api-client

# %%
from twitter.search import Search

email, username, password = "we444465@gmail.com", "DarOho4050", "asdfghjkl1!"
# default output directory is `data/search_results` if save=True
search = Search(email, username, password, save=True, debug=1)

# %%
res = search.run(
    limit=100,
    retries=5,
    latest=True
    queries=[
        {
            'category': 'Latest',
            'query': 'Tesla'
        },
    ],
)
print(res)

# %%
# %pip install git+https://github.com/vladkens/twscrape.git
# %pip install langdetect

# %%
import asyncio
from twscrape import API, gather
from twscrape.logger import set_log_level
import json
import time
from langdetect import detect, LangDetectException
import re


search_term = "Tesla OR TSLA"
async def main():
    api = API()  # or API("path-to.db") - default is `accounts.db`

    # ADD ACCOUNTS (for CLI usage see BELOW)
    await api.pool.add_account("DarOho4050", "asdfghjkl1!", "we444465@gmail.com", "mail_pass1")
    # await api.pool.add_account("user2", "pass2", "u2@example.com", "mail_pass2")
    await api.pool.login_all()

# search (latest tab)
    tweets = await gather(api.search(search_term, limit=50))  # list[Tweet]
    print(tweets)
    
    def user_to_dict(user):
        return {
            'id': user.id,
            'id_str': user.id_str,
            'url': user.url,
            'username': user.username,
            'displayname': user.displayname,
            'rawDescription': user.rawDescription,
            'created': user.created.isoformat() if user.created else None,            
        }
    
    def tweet_to_dict(tweet):
        return {
            'id': tweet.id,
            'date': tweet.date.isoformat(),
            'rawContent': tweet.rawContent,
            'url': tweet.url,
            'user': user_to_dict(tweet.user),
            'lang': tweet.lang,
            'replyCount': tweet.replyCount,
            'retweetCount': tweet.retweetCount,
            'likeCount': tweet.likeCount,
            'quoteCount': tweet.quoteCount
        }

    # Convert each Tweet instance to a dictionary
    tweets_as_dicts = [tweet_to_dict(tweet) for tweet in tweets]
    print(tweets_as_dicts)
    return tweets_as_dicts
    
def write_tweets_to_file(tweets, file_path):
    """Generic function to write tweets to a specified file with deduplication."""
    new_tweets_count = 0
    existing_ids = set()
    try:
        with open(file_path, 'r') as file:
            existing_ids.update(json.loads(line)['id'] for line in file)
    except FileNotFoundError:
        pass  # It's okay if the file does not exist yet

    with open(file_path, 'a') as file:
        for tweet in tweets:
            if tweet['id'] not in existing_ids:
                file.write(json.dumps(tweet) + '\n')
                new_tweets_count += 1
                existing_ids.add(tweet['id'])

    return new_tweets_count
    
def clean_tweet_content(text):
    """Remove mentions and links from tweet text."""
    text = re.sub(r'@\w+', '', text)  # Remove mentions
    text = re.sub(r'https?://\S+', '', text)  # Remove URLs
    return text.strip()

def matches_search_criteria(tweet_content, search_terms):
    """Check if tweet content matches the search criteria using regex for flexibility."""
    # For simplicity, this example focuses on 'OR' logic. It can be extended for 'AND'.
    search_terms = search_terms.replace(' OR ', '|')  # Replace 'OR' with regex '|' for alternation
    pattern = r'\b(' + search_terms + r')\b'  # Word boundary regex to match whole words only
    return re.search(pattern, tweet_content, re.IGNORECASE) is not None

def filter_tweets(tweets):
    english_tweets = []
    filtered_tweets = []  # Tweets filtered out
    for tweet in tweets:
        # Remove mentions from the tweet's rawContent
        cleaned_content = clean_tweet_content(tweet['rawContent'])
        if matches_search_criteria(cleaned_content.lower(), search_term.lower()):
            try:
                if detect(cleaned_content) == 'en':
                    english_tweets.append(tweet)
                else:
                    filtered_tweets.append(tweet)
            except LangDetectException:
                # Assume English if detection fails
                english_tweets.append(tweet)
    return english_tweets, filtered_tweets

def write_english_tweets(tweets):
    """Write English tweets to their file."""
    return write_tweets_to_file(tweets, 'english_tweets.jsonl')

def write_filtered_tweets(tweets):
    """Write filtered (non-English) tweets to their file."""
    return write_tweets_to_file(tweets, 'filtered_tweets.jsonl')


while True:
    tweets = await main()  # Assume this fetches a list of tweet dictionaries
    english_tweets, filtered_tweets = filter_tweets(tweets)
    
    new_english_count = write_english_tweets(english_tweets)
    filtered_count = write_filtered_tweets(filtered_tweets)
    
    total_processed = len(english_tweets) + len(filtered_tweets)
    
    if total_processed > 0:
        english_percentage = (new_english_count / total_processed) * 100
        filtered_percentage = (filtered_count / total_processed) * 100
        print(f"Processed {total_processed} tweets. New English: {english_percentage:.2f}%. Filtered: {filtered_percentage:.2f}%.")
    else:
        print("No tweets to process.")

    time.sleep(90)  # Sleep for x seconds
    
if __name__ == "__main__":
    tweets = await main()  # Should return a list of tweet dictionaries
new_tweets_count, total_tweets = write_tweets_to_jsonl(tweets)
    
if total_tweets > 0:  # Prevent division by zero
    new_tweets_percentage = (new_tweets_count / total_tweets) * 100
    print(f"New tweets: {new_tweets_count} of {total_tweets} - {new_tweets_percentage:.2f}% new")
else:
    print("No tweets to process.")
# Out:
# 2024-02-05 04:58:29.041 | WARNING  | twscrape.accounts_pool:add_account:76 - Account DarOho4050 already exists
# [Tweet(id=1754368874152095806, id_str='1754368874152095806', url='https://twitter.com/DirtyTesLa/status/1754368874152095806', date=datetime.datetime(2024, 2, 5, 4, 58, 28, tzinfo=datetime.timezone.utc), user=User(id=1118594454515003393, id_str='1118594454515003393', url='https://twitter.com/DirtyTesLa', username='DirtyTesLa', displayname='Dirty Tesla', rawDescription='YouTube and Merch: https://t.co/xDxdMQtRrJ\n\nMS, Biology; Anti-sleep\n\nAi', created=datetime.datetime(2019, 4, 17, 19, 17, 55, tzinfo=datetime.timezone.utc), followersCount=95064, friendsCount=960, statusesCount=79521, favouritesCount=264613, listedCount=921, mediaCount=7932, location='Michigan', profileImageUrl='https://pbs.twimg.com/profile_images/1515173488008572931/VYTdzMib_normal.jpg', profileBannerUrl='https://pbs.twimg.com/profile_banners/1118594454515003393/1689815500', protected=None, verified=False, blue=True, blueType=None, descriptionLinks=[TextLink(url='http://bio.link/dirtytesla', text='bio.link/dirtytesla', tcourl='https://t.co/xDxdMQtRrJ'), TextLink(url='http://www.youtube.com/c/dirtytesla', text='youtube.com/c/dirtytesla', tcourl='https://t.co/VLsOitxfDp')], _type='snscrape.modules.twitter.User'), lang='en', rawContent='Tho I basically never do this. I just sit at my computer and use it normally.', replyCount=0, retweetCount=0, likeCount=0, quoteCount=0, conversationId=1754366184877629674, hashtags=[], cashtags=[], mentionedUsers=[], links=[], viewCount=None, retweetedTweet=None, quotedTweet=None, place=None, coordinates=None, inReplyToTweetId=1754366184877629674, inReplyToUser=UserRef(id=1118594454515003393, username='DirtyTesLa', displayname='Dirty Tesla', _type='snscrape.modules.twitter.UserRef'), source='<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', sourceUrl='http://twitter.com/download/android', sourceLabel='Twitter for Android', media=Media(photos=[], videos=[], animated=[]), _type='snscrape.modules.twitter.Tweet'), Tweet(id=1754368870197199133, id_str='1754368870197199133', url='https://twitter.com/CranstonDwayne/status/1754368870197199133', date=datetime.datetime(2024, 2, 5, 4, 58, 27, tzinfo=datetime.timezone.utc), user=User(id=1355097037931311104, id_str='1355097037931311104', url='https://twitter.com/CranstonDwayne', username='CranstonDwayne', displayname='Dwayne Cranston', rawDescription='', created=datetime.datetime(2021, 1, 29, 10, 15, 22, tzinfo=datetime.timezone.utc), followersCount=552, friendsCount=334, statusesCount=4231, favouritesCount=12734, listedCount=2, mediaCount=19, location='', profileImageUrl='https://pbs.twimg.com/profile_images/1694910018771136512/98F-AWe6_normal.jpg', profileBannerUrl=None, protected=None, verified=False, blue=True, blueType=None, descriptionLinks=[], _type='snscrape.modules.twitter.User'), lang='en', rawContent='My line of thinking is the following…\n\nTesla appeals the verdict while simultaneously moving corporate governance to Texas or Nevada. \n\nOnce in the new jurisdiction, issue a backdated comp plan to make Elon whole in addition to a new plan we can all agree to with the caveat that if he wins the appeal (huge benefit for Tesla and all companies residing in Delaware) that the backdated plan will cease to exist. \n\nThis would be as close to a no lose situation as possible and might be incredibly positive for Tesla and all public companies.', replyCount=0, retweetCount=0, likeCount=0, quoteCount=0, conversationId=1754347416768200794, hashtags=[], cashtags=[], mentionedUsers=[UserRef(id=2361631088, username='CathieDWood', displayname='Cathie Wood', _type='snscrape.modules.twitter.UserRef'), UserRef(id=44196397, username='elonmusk', displayname='Elon Musk', _type='snscrape.modules.twitter.UserRef')], links=[], viewCount=None, retweetedTweet=None, quotedTweet=None, place=None, coordinates=None, inReplyToTweetId=1754347416768200794, inReplyToUser=UserRef(id=2361631088, username='CathieDWood', displayname='Cathie Wood', _type='snscrape.modules.twitter. ...
# [{'id': 1754368874152095806, 'date': '2024-02-05T04:58:28+00:00', 'rawContent': 'Tho I basically never do this. I just sit at my computer and use it normally.', 'url': 'https://twitter.com/DirtyTesLa/status/1754368874152095806', 'user': {'id': 1118594454515003393, 'id_str': '1118594454515003393', 'url': 'https://twitter.com/DirtyTesLa', 'username': 'DirtyTesLa', 'displayname': 'Dirty Tesla', 'rawDescription': 'YouTube and Merch: https://t.co/xDxdMQtRrJ\n\nMS, Biology; Anti-sleep\n\nAi', 'created': '2019-04-17T19:17:55+00:00'}, 'lang': 'en', 'replyCount': 0, 'retweetCount': 0, 'likeCount': 0, 'quoteCount': 0}, {'id': 1754368870197199133, 'date': '2024-02-05T04:58:27+00:00', 'rawContent': 'My line of thinking is the following…\n\nTesla appeals the verdict while simultaneously moving corporate governance to Texas or Nevada. \n\nOnce in the new jurisdiction, issue a backdated comp plan to make Elon whole in addition to a new plan we can all agree to with the caveat that if he wins the appeal (huge benefit for Tesla and all companies residing in Delaware) that the backdated plan will cease to exist. \n\nTh