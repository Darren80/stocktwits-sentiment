# %% [markdown]
# # Imports

# %%
# !pip install yfinance --upgrade --no-cache-dir
# !pip install finnhub-python
# !pip3 install news-please

# !pip install torch
# !pip install peft
# !pip install -U accelerate
# !pip install transformers bitsandbytes
# !pip install pynvml
# !pip install gnews
# !pip install selenium
# !pip install webdriver_manager
# !pip install --upgrade undetected-chromedriver
# !pip install -U selenium

# %% [markdown]
# News from other sources (Google)

# %%
# !pip3 install newspaper3k
from gnews import GNews
import json
from datetime import datetime
import time

ticker = "TSLA"
search_term = "Tesla stock"

file_path = f"{ticker}_news.jsonl"
google_news = GNews()
def get_news(search_terms):
    stock_news = google_news.get_news(search_terms)
    # Define a function to convert date strings into datetime objects
    def parse_date(date_str):
        # Example date: "Thu, 08 Feb 2024 15:35:00 GMT"
        return datetime.strptime(date_str, '%a, %d %b %Y %H:%M:%S GMT')

    # Sort stock_news by parsed 'publish date'
    stock_news = sorted(stock_news, key=lambda x: parse_date(x['published date']), reverse=True)
    
    return stock_news

def get_content(url, homepage_url):
    article = google_news.get_full_article(url, homepage_url)
    return article

import json
from dateutil import parser

def write_articles_to_file(articles, file_path):
    """Function to update or add articles, not adding an article if the title matches an existing record and the published date is within 1 day."""
    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            existing_articles = [json.loads(line) for line in file]
    except FileNotFoundError:
        existing_articles = []

    existing_articles_dict = {}
    for article in existing_articles:
        article_date = parser.parse(article['published date'])
        if article['title'] not in existing_articles_dict:
            existing_articles_dict[article['title']] = []
        existing_articles_dict[article['title']].append(article_date)

    updated = False  # Flag to track if any article was updated or added
    number = 0

    for article in articles:
        article_date = parser.parse(article['published date'])
        add_article = True
        # Check if the article title exists
        if article['title'] in existing_articles_dict:
            for existing_article_date in existing_articles_dict[article['title']]:
                # Check if the published date is within 1 day of the existing article
                if abs((article_date - existing_article_date).days) <= 1:
                    add_article = False
                    break
        
        if add_article:
            if article['title'] not in existing_articles_dict:
                existing_articles_dict[article['title']] = []
            existing_articles_dict[article['title']].append(article_date)
            existing_articles.append(article)  # Add article to the list for writing back to file
            updated = True
            number += 1

    # Write back to the file only if there was an update
    if updated:
        with open(file_path, 'w', encoding='utf-8') as file:
            for article in existing_articles:
                file.write(json.dumps(article, ensure_ascii=False) + '\n')

    print("New Articles?", updated, ":", number)
    return len(articles)  # Returning count of processed articles for simplicity


def load_articles_with_empty_content(file_path):
    """Load articles from a file, returning only those with empty or missing 'content'."""
    articles_with_empty_content = []

    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                article = json.loads(line)
                # Check if 'content' is missing or empty
                if not article.get('content'):
                    articles_with_empty_content.append(article)
    except FileNotFoundError:
        print(f"No file found at {file_path}")
    
    return articles_with_empty_content

def load_articles_with_full_content(file_path):
    """Load articles from a file, returning only those with empty or missing 'content'."""
    articles_with_empty_content = []

    try:
        with open(file_path, 'r', encoding='utf-8') as file:
            for line in file:
                article = json.loads(line)
                # Check if 'content' is missing or empty
                if article.get('content'):
                    articles_with_empty_content.append(article)
    except FileNotFoundError:
        print(f"No file found at {file_path}")
    
    return articles_with_empty_content

def parse_date(date_str):
    # Example date: "Thu, 08 Feb 2024 15:35:00 GMT"
    return datetime.strptime(date_str, '%a, %d %b %Y %H:%M:%S GMT')
# Out:
# C:\Users\bow33\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\__init__.py:102: RequestsDependencyWarning: urllib3 (1.26.18) or chardet (5.2.0)/charset_normalizer (2.0.12) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({})/charset_normalizer ({}) doesn't match a supported "

# %% [markdown]
# Entry point for the scraping process to get their contents

# %%
exclude = ['wsj.com', 'fool.com']

# Only do x articles before continuing (for loop, a skipped article does not count as a step)
def get_news_content(stock_news, file_path, articles_to_scrape=20):
    print("Articles Unscraped:", len(stock_news))
    for i, article in enumerate(stock_news):
        if any(excluded_domain in article['publisher']['href'] for excluded_domain in exclude):
            print("Closed due to  domain exclusion: ", article['publisher']['href'])
            continue
        
        article['content'] = get_content(article['url'], article['publisher']['href']).text
        article = [article]
        
        print("+_+_+_+_Content: ", article[0]['content'][:100])
        
        write_articles_to_file(article, file_path)
        print(articles_to_scrape, "left")
        
        articles_to_scrape -= 1
        if articles_to_scrape == 0:
            break

# %% [markdown]
# Start the process every x seconds

# %%
while True:
    stock_news = get_news(search_term)
    write_articles_to_file(stock_news, file_path)
    print(stock_news)

    unscrapped_stock_news = load_articles_with_empty_content(file_path)
    unscrapped_stock_news = sorted(unscrapped_stock_news, key=lambda x: parse_date(x['published date']), reverse=True)
    get_news_content(unscrapped_stock_news, file_path)
    
    print("Sleeping")
    for i in range(60):
        time.sleep(1)
# Out:
# New Articles? True : 12
# [{'title': 'Rivian Stock Plummets 15% After Layoffs Announced - Forbes', 'description': 'Rivian Stock Plummets 15% After Layoffs Announced  Forbes', 'published date': 'Wed, 21 Feb 2024 23:46:10 GMT', 'url': 'https://news.google.?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://www.forbes.com', 'title': 'Forbes'}}, {'title': 'Best Artificial Intelligence (AI) Stock: Palantir vs. Tesla vs. Super Micro Computer - The Globe and Mail', 'description': 'Best Artificial Intelligence (AI) Stock: Palantir vs. Tesla vs. Super Micro Computer  The Globe and Mail', 'published date': 'Wed, 21 Feb 2024 21:45:00 GMT', 'url': 'https://news.google.com/rss/articles/CBMipQFodHRwczovL3d3dy50aGVnbG9iZWFuZG1haWwuY29tL2ludmVzdGluZy9tYXJrZXRzL3N0b2Nrcy9UU0xBL3ByZXNzcmVsZWFzZXMvMjQyNDU1ODYvYmVzdC1hcnRpZmljaWFsLWludGVsbGlnZW5jZS1haS1zdG9jay1wYWxhbnRpci12cy10ZXNsYS12cy1zdXBlci1taWNyby1jb21wdXRlci_SAQA?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://www.theglobeandmail.com', 'title': 'The Globe and Mail'}}, {'title': "Magnificent Seven Stocks To Buy And Watch: Nvidia Earnings Loom - Investor's Business Daily", 'description': "Magnificent Seven Stocks To Buy And Watch: Nvidia Earnings Loom  Investor's Business Daily", 'published date': 'Wed, 21 Feb 2024 20:22:00 GMT', 'url': 'https://news.google.com/rss/articles/CBMiUWh0dHBzOi8vd3d3LmludmVzdG9ycy5jb20vcmVzZWFyY2gvbWFnbmlmaWNlbnQtc2V2ZW4tc3RvY2tzLXRvLWJ1eS1hbmQtYW5kLXdhdGNoL9IBAA?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://www.investors.com', 'title': "Investor's Business Daily"}}, {'title': 'Tesla faces hurdle in Germany as locals vote to oppose factory expansion - CNBC', 'description': 'Tesla faces hurdle in Germany as locals vote to oppose factory expansion  CNBC', 'published date': 'Wed, 21 Feb 2024 18:29:46 GMT', 'url': 'https://news.google.?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://www.cnbc.com', 'title': 'CNBC'}}, {'title': 'Best Artificial Intelligence (AI) Stock: Palantir vs. Tesla vs. Super Micro Computer - The Motley Fool', 'description': 'Best Artificial Intelligence (AI) Stock: Palantir vs. Tesla vs. Super Micro Computer  The Motley Fool', 'published date': 'Wed, 21 Feb 2024 18:07:15 GMT', 'url': 'https://news.google.com/rss/articles/CBMiXGh0dHBzOi8vd3d3LmZvb2wuY29tL2ludmVzdGluZy8yMDI0LzAyLzIxL2Jlc3QtYXJ0aWZpY2lhbC1pbnRlbGxpZ2VuY2UtYWktc3RvY2stcGFsYW50aXItdnMv0gEA?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://www.fool.com', 'title': 'The Motley Fool'}}, {'title': 'Best Artificial Intelligence (AI) Stock: Palantir vs. Tesla vs. Super Micro Computer - Yahoo Finance', 'description': 'Best Artificial Intelligence (AI) Stock: Palantir vs. Tesla vs. Super Micro Computer  Yahoo Finance', 'published date': 'Wed, 21 Feb 2024 18:07:15 GMT', 'url': 'https://news.google.com/rss/articles/CBMiU2h0dHBzOi8vZmluYW5jZS55YWhvby5jb20vbmV3cy9iZXN0LWFydGlmaWNpYWwtaW50ZWxsaWdlbmNlLWFpLXN0b2NrLTE4MDcxNTA2MS5odG1s0gEA?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://finance.yahoo.com', 'title': 'Yahoo Finance'}}, {'title': 'Broadcom, The Magnificent 7 Stock In Waiting: Can The Chipmaker Replace EV Carmaker Tesla? - NVIDIA (NASD - Benzinga', 'description': 'Broadcom, The Magnificent 7 Stock In Waiting: Can The Chipmaker Replace EV Carmaker Tesla? - NVIDIA (NASD ...
# Articles Unscraped: 81
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Fool.com contributor Parkev Tatevosian decides which artificial intelligence (AI) stock is the best
# New Articles? False : 0
# 20 left
# Closed due to  domain exclusion:  https://www.fool.com
# Closed due to  domain exclusion:  https://www.fool.com
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:
# New Articles? False : 0
# 19 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Second time’s the charm—or that’s perhaps what Henrik Fisker thought as he launched the eponymous EV
# New Articles? False : 0
# 18 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Key Points Tesla's shares have dropped nearly 20% year-to-date and 15% over the last three months, d
# New Articles? False : 0
# 17 left
# Closed due to  domain exclusion:  https://www.fool.com
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  For Immediate Release
#
# Chicago, IL – February 20, 2024 – Today, Zacks Investment Ideas feature highl
# New Articles? False : 0
# 16 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  NEW LOOK Sign up to get the inside scoop on today’s biggest stories in markets, tech, and business —
# New Articles? False : 0
# 15 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  BYD overtook Tesla as a the biggest maker of electric vehicles in the fourth quarter.
#
# Chinese elect
# New Articles? False : 0
# 14 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Authored by Michael Lebowitz via RealInvestmentAdvice.com,
#
# Over the last four quarters, Tesla gener
# New Articles? False : 0
# 13 left
# Closed due to  domain exclusion:  https://www.fool.com
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  With the U.S. stock markets hitting new record highs almost every day, the term “cheap growth stocks
# New Articles? False : 0
# 12 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Finding stocks to buy has become increasingly difficult as the market has rocketed higher. Intrepid
# New Articles? False : 0
# 11 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Shares of Tesla Inc. TSLA, +0.52% dropped 0.25% to $199.95 Friday, on what proved to be an all-aroun
# New Articles? False : 0
# 10 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Cathie Wood's ARK Invest ETFs were some of the hottest funds after 2020's huge stock market gains an
# New Articles? False : 0
# 9 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Tesla stock is trying to make it three consecutive days of gains on Friday.
#
# Shares were 1.5% higher
# New Articles? False : 0
# 8 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Tesla Inc. is a car manufacturer that pitches itself, very successfully, as a technology hothouse. S
# New Articles? False : 0
# 7 left
# Closed due to  domain exclusion:  https://www.wsj.com
# Closed due to  domain exclusion:  https://www.fool.com
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  The bears are targeting Tesla (NASDAQ:TSLA) with sharpened claws at the moment. With that in mind, m
# New Articles? False : 0
# 6 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Tesla stock closed higher for a second straight day, but moves in the Treasury market seem to have m
# New Articles? False : 0
# 5 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  TSLA +0.52% Add to/Remove from Watchlist IXIC -0.32% Add to/Remove from Watchlist
#
# Shares have been
# New Articles? False : 0
# 4 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Tesla CEO Elon Musk now owns a 20.5% stake in the company, according to a new SEC filing, meaning th
# New Articles? False : 0
# 3 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Most of the so-called “Magnificent Seven” tech stocks are having a pretty good year. Apple stock is
# New Articles? False : 0
# 2 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Elon Musk's ownership stake in Tesla is 20.5% and is worth more than $120 billion.
#
# A new SEC filing
# New Articles? False : 0
# 1 left
# Sleeping
# New Articles? True : 17
# [{'title': 'Rivian Stock Plummets 15% After Layoffs Announced - Forbes', 'description': 'Rivian Stock Plummets 15% After Layoffs Announced  Forbes', 'published date': 'Wed, 21 Feb 2024 23:46:10 GMT', 'url': 'https://news.google.?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://www.forbes.com', 'title': 'Forbes'}}, {'title': "Tesla Falls Further. It's Overtaken as Most Traded Stock on Wall Street. - Barron's", 'description': "Tesla Falls Further. It's Overtaken as Most Traded Stock on Wall Street.  Barron's", 'published date': 'Wed, 21 Feb 2024 22:33:00 GMT', 'url': 'https://news.google.com/rss/articles/CBMipgFodHRwczovL3d3dy5iYXJyb25zLmNvbS9saXZlY292ZXJhZ2Uvc3RvY2stbWFya2V0LXRvZGF5LTAyMjEyNC9jYXJkL3Rlc2xhLXN0b2NrLWZhbGxzLWZ1cnRoZXItaXQtcy1vdmVydGFrZW4tYXMtbW9zdC10cmFkZWQtc3RvY2stb24td2FsbC1zdHJlZXQtLWh6S1k4ZlQ2VUNGRWhld3hMU2pB0gEA?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://www.barrons.com', 'title': "Barron's"}}, {'title': 'Nvidia Flips Tesla as Wallstreet Most Traded Stock Amidst AI-Fueled Trading Frenzy - The Tech Report', 'description': 'Nvidia Flips Tesla as Wallstreet Most Traded Stock Amidst AI-Fueled Trading Frenzy  The Tech Report', 'published date': 'Wed, 21 Feb 2024 21:59:07 GMT', 'url': 'https://news.google.com/rss/articles/CBMib2h0dHBzOi8vdGVjaHJlcG9ydC5jb20vbmV3cy9udmlkaWEtZmxpcHMtdGVzbGEtYXMtd2FsbHN0cmVldC1tb3N0LXRyYWRlZC1zdG9jay1hbWlkc3QtYWktZnVlbGVkLXRyYWRpbmctZnJlbnp5L9IBAA?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://techreport.com', 'title': 'The Tech Report'}}, {'title': 'Best Artificial Intelligence (AI) Stock: Palantir vs. Tesla vs. Super Micro Computer - The Globe and Mail', 'description': 'Best Artificial Intelligence (AI) Stock: Palantir vs. Tesla vs. Super Micro Computer  The Globe and Mail', 'published date': 'Wed, 21 Feb 2024 21:45:00 GMT', 'url': 'https://news.google.com/rss/articles/CBMipQFodHRwczovL3d3dy50aGVnbG9iZWFuZG1haWwuY29tL2ludmVzdGluZy9tYXJrZXRzL3N0b2Nrcy9UU0xBL3ByZXNzcmVsZWFzZXMvMjQyNDU1ODYvYmVzdC1hcnRpZmljaWFsLWludGVsbGlnZW5jZS1haS1zdG9jay1wYWxhbnRpci12cy10ZXNsYS12cy1zdXBlci1taWNyby1jb21wdXRlci_SAQA?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://www.theglobeandmail.com', 'title': 'The Globe and Mail'}}, {'title': "Magnificent Seven Stocks To Buy And Watch: Nvidia Earnings Loom - Investor's Business Daily", 'description': "Magnificent Seven Stocks To Buy And Watch: Nvidia Earnings Loom  Investor's Business Daily", 'published date': 'Wed, 21 Feb 2024 20:22:00 GMT', 'url': 'https://news.google.com/rss/articles/CBMiUWh0dHBzOi8vd3d3LmludmVzdG9ycy5jb20vcmVzZWFyY2gvbWFnbmlmaWNlbnQtc2V2ZW4tc3RvY2tzLXRvLWJ1eS1hbmQtYW5kLXdhdGNoL9IBAA?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://www.investors.com', 'title': "Investor's Business Daily"}}, {'title': 'Tesla faces hurdle in Germany as locals vote to oppose factory expansion - CNBC', 'description': 'Tesla faces hurdle in Germany as locals vote to oppose factory expansion  CNBC', 'published date': 'Wed, 21 Feb 2024 18:29:46 GMT', 'url': 'https://news.google.?oc=5&hl=en-GB&gl=GB&ceid=GB:en', 'publisher': {'href': 'https://www.cnbc.com', 'title': 'CNBC'}}, {'title': 'Best Artificial Intelligence (AI) Stock: Palantir vs. Tesla vs. Super Micro Computer - The Motley Fool', 'description': 'Best Artificial Intellig ...
# Articles Unscraped: 98
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Santa Clara-based chipmaker Nvidia has emerged as Wall Street’s new king of trading activity, dethro
# New Articles? False : 0
# 20 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Fool.com contributor Parkev Tatevosian decides which artificial intelligence (AI) stock is the best
# New Articles? False : 0
# 19 left
# Closed due to  domain exclusion:  https://www.fool.com
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Wednesday’s stock sentiment will hinge on the technology sector. After a euphoric multi-year run-up,
# New Articles? False : 0
# 18 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Cathie Wood said Nvidia "has become a check-the-box stock."
#
# Wood said she'd been selling the stock
# New Articles? False : 0
# 17 left
# Closed due to  domain exclusion:  https://www.fool.com
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:
# New Articles? False : 0
# 16 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Second time’s the charm—or that’s perhaps what Henrik Fisker thought as he launched the eponymous EV
# New Articles? False : 0
# 15 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Tesla (NASDAQ: TSLA ) remains the world’s most valuable car company. Despite the stock being down al
# New Articles? False : 0
# 14 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Key Points Tesla's shares have dropped nearly 20% year-to-date and 15% over the last three months, d
# New Articles? False : 0
# 13 left
# Closed due to  domain exclusion:  https://www.fool.com
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  For Immediate Release
#
# Chicago, IL – February 20, 2024 – Today, Zacks Investment Ideas feature highl
# New Articles? False : 0
# 12 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  NEW LOOK Sign up to get the inside scoop on today’s biggest stories in markets, tech, and business —
# New Articles? False : 0
# 11 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  BYD overtook Tesla as a the biggest maker of electric vehicles in the fourth quarter.
#
# Chinese elect
# New Articles? False : 0
# 10 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Authored by Michael Lebowitz via RealInvestmentAdvice.com,
#
# Over the last four quarters, Tesla gener
# New Articles? False : 0
# 9 left
# Closed due to  domain exclusion:  https://www.fool.com
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  With the U.S. stock markets hitting new record highs almost every day, the term “cheap growth stocks
# New Articles? False : 0
# 8 left
# The 'Accept all' button was not found within the given time.
# +_+_+_+_Content:  Finding stocks to buy has become increasingly difficult as the market has rocketed higher. Intrepid
# New Articles? False : 0
# 7 left
# The 'Accept all' button was not found within the given time.
